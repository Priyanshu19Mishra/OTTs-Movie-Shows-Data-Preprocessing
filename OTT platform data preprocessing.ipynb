# %% [markdown]
# Loading the Dataset OTTS-Movie&Shows.csv

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

csv_path = '/content/drive/MyDrive/OTTs-Movie&Shows.csv'


data = pd.read_csv(csv_path)  #loading of the dataset

print(data.head()) # printing the dataset
# Out:
#    Unnamed: 0 show_id   type                 title        director  \
# 0           0      s1  Movie   The Grand Seduction    Don McKellar
# 1           1      s2  Movie  Take Care Good Night    Girish Joshi
# 2           2      s3  Movie  Secrets of Deception     Josh Webber
# 3           3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4           4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# ...

# %% [markdown]
# Getting the shape of the dataset

# %%
data.shape
# Out:
# (22998, 14)

# %% [markdown]
# Getting the description of the data

# %%
data.describe()
# Out:
#          Unnamed: 0  release_year
# count  22998.000000  22998.000000
# mean   11498.500000   2010.811244
# std     6639.095081     15.401142
# min        0.000000   1920.000000
# 25%     5749.250000   2010.000000
# 50%    11498.500000   2016.000000
# 75%    17247.750000   2019.000000
# max    22997.000000   2021.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['release_year'].plot(kind='hist', bins=20, title='release_year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %% [markdown]
# Data Description

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22998 entries, 0 to 22997
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    22998 non-null  int64
#  1   show_id       22998 non-null  object
#  2   type          22998 non-null  object
#  3   title         22998 non-null  object
#  4   director      14739 non-null  object
#  5   cast          17677 non-null  object
#  6   country       11499 non-null  object
#  7   date_added    13444 non-null  object
#  8   release_year  22998 non-null  int64
#  9   rating        22134 non-null  object
#  10  duration      22516 non-null  object
#  11  listed_in     22998 non-null  object
#  12  description   22994 non-null  object
#  13  platform      22998 non-null  object
# dtypes: int64(2), object(12)
# memory usage: 2.5+ MB

# %% [markdown]
# Cleaning of Data

# %% [markdown]
# checking for the duplicate values

# %%
data1=data.drop_duplicates(inplace=True)
print(data1)
# Out:
# None

# %% [markdown]
# Checking for the null values in different coloums

# %%
data.isnull().sum()
# Out:
# Unnamed: 0          0
# show_id             0
# type                0
# title               0
# director         8259
# cast             5321
# country         11499
# date_added       9554
# release_year        0
# rating            864
# duration          482
# listed_in           0
# description         4
# platform            0
# dtype: int64

# %% [markdown]
# Dropping the coloumns with max null values

# %%
# data.drop(columns=['show_id','type','title','director','cast','country','date_added','release_year','rating','duration','listed_in','description','platform'],inplace=True)

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Visualization for getting the mean and median of the "Release_Year" coloumn. To get the mean year and the median year for the release of the movies and the TV Shows data set

# %%
sns.distplot(data['release_year'])
print('Mean:', data['release_year'].mean(), 'Median:', data['release_year'].median())
# Out:
# <ipython-input-13-475b0ee5f273>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['release_year'])
# Mean: 2010.8112444560397 Median: 2016.0

# %%
data['rating'].value_counts()
# Out:
# TV-MA     3675
# TV-14     3138
# R         2154
# 13+       2117
# TV-PG     1654
#           ...
# 34 min       1
# 47 min       1
# 65 min       1
# 67 min       1
# 71 min       1
# Name: rating, Length: 105, dtype: int64

# %%
data['release_year'].value_counts()
# Out:
# 2019    2470
# 2020    2406
# 2021    2385
# 2018    2105
# 2017    1892
#         ...
# 1923       2
# 1922       2
# 1924       1
# 1927       1
# 1928       1
# Name: release_year, Length: 101, dtype: int64

# %%
data['duration'].value_counts()
# Out:
# 1 Season      4183
# 2 Seasons     1001
# 3 Seasons      475
# 90 min         429
# 91 min         419
#               ...
# 212 min          1
# 207 min          1
# 273 min          1
# 269 min          1
# 26 Seasons       1
# Name: duration, Length: 253, dtype: int64

# %%
data['duration'].replace({'1 Season': '320 min'},inplace=True)
data['duration'].replace({'2 Season':'640 min'},inplace=True)
data['duration'].replace({'4 Seasons':'1280 min'},inplace=True)
data['duration'].replace({'3 Season':'960 min'},inplace=True)
data['rating'].replace({'TV-Y':2-6},inplace=True)
data['rating'].replace({'TV-Y7':7},inplace=True)
data['rating'].replace({'TV-NR':18},inplace=True)
data['rating'].replace({'TV-MA':18},inplace=True)
data['rating'].replace({'TV-PG':7},inplace=True)
data['rating'].replace({'R':18},inplace=True)
data['rating'].replace({'G':0},inplace=True)
data['rating'].replace({'NR':0},inplace=True)
data['rating'].replace({'PG-13':13},inplace=True)
data['rating'].replace({'TV-14':14},inplace=True)
data['rating'].replace({'16+':16},inplace=True)
data['rating'].replace({'13+':13},inplace=True)
data['rating'].replace({'16+':16},inplace=True)
data['rating'].replace({'18+':18},inplace=True)
data['rating'].replace({'ALL':0},inplace=True)
data['rating'].replace({'7+':7},inplace=True)

# %%
data.head(50)
# Out:
#     Unnamed: 0 show_id     type  \
# 0            0      s1    Movie
# 1            1      s2    Movie
# 2            2      s3    Movie
# 3            3      s4    Movie
# 4            4      s5    Movie
# 5            5      s6    Movie
# 6            6      s7    Movie
# 7            7      s8    Movie
# 8            8      s9    Movie
# 9            9     s10    Movie
# 10          10     s11    Movie
# 11          11     s12    Movie
# 12          12     s13    Movie
# 13          13     s14    Movie
# 14          14     s15    Movie
# 15          15     s16    Movie
# 16          16     s17    Movie
# 17          17     s18  TV Show
# 18          18     s19  TV Show
# 19          19     s20    Movie
# 20          20     s21  TV Show
# 21          21     s22  TV Show
# 22          22     s23    Movie
# 23          23     s24  TV Show
# 24          24     s25    Movie
# 25          25     s26    Movie
# 26          26     s27  TV Show
# 27          27     s28  TV Show
# ...

# %% [markdown]
# Filling in the null values with the 0 in the dataset

# %%
data.fillna(0,inplace=True)

# %%
data.head()
# Out:
#    Unnamed: 0 show_id   type                 title        director  \
# 0           0      s1  Movie   The Grand Seduction    Don McKellar
# 1           1      s2  Movie  Take Care Good Night    Girish Joshi
# 2           2      s3  Movie  Secrets of Deception     Josh Webber
# 3           3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4           4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# ...

# %%
platform_counts=data['platform'].value_counts()

# %% [markdown]
# Spliting of the coloumn (that contain all the platform detail in a single column) into Netflix_data, Amazon_data, Disney+Hotstar_data, Hulu_data

# %%
data['Netflix_data'] = data['platform'].apply(lambda x: 1 if x == 'Netflix' else 0)
data['Amazon_data'] = data['platform'].apply(lambda x: 1 if x == 'Amazon Prime' else 0)
data['Disney+Hotstar_data'] = data['platform'].apply(lambda x: 1 if x == 'Disney+Hotstar' else 0)
data['Hulu_data'] = data['platform'].apply(lambda x: 1 if x == 'Hulu' else 0)

# %%
data.head()
# Out:
#    Unnamed: 0 show_id   type                 title        director  \
# 0           0      s1  Movie   The Grand Seduction    Don McKellar
# 1           1      s2  Movie  Take Care Good Night    Girish Joshi
# 2           2      s3  Movie  Secrets of Deception     Josh Webber
# 3           3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4           4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# ...

# %% [markdown]
# Bar graph to show number of movies under differen platform

# %%
sns.barplot(x=platform_counts.index, y=platform_counts.values)
plt.xlabel('Platform')
plt.ylabel('Number of Movies')
plt.title('Number of Movies on Different Platforms')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Creating coloumn for different types for MOvie and TV Shows.

# %%
type_counts=data['type'].value_counts()

# %%
data['Movie_Data'] = data['type'].apply(lambda x: 1 if x == 'Movie' else 0)
data['TV_Show_Data'] = data['type'].apply(lambda x: 1 if x == 'TV Show' else 0)

# %%
data.head()
# Out:
#    Unnamed: 0 show_id   type                 title        director  \
# 0           0      s1  Movie   The Grand Seduction    Don McKellar
# 1           1      s2  Movie  Take Care Good Night    Girish Joshi
# 2           2      s3  Movie  Secrets of Deception     Josh Webber
# 3           3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4           4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# ...

# %%
sns.barplot(x=type_counts.index, y=type_counts.values)
plt.xlabel('Types')
plt.ylabel('Numbers')
plt.title('Number of shows')
plt.xticks(rotation=45)
plt.show()

# %%
print('Movies released from the year %d are available in the above OTT platforms '%(data['release_year'].min()))
print('Many movies released in the year %d are available in the above OTT platforms '%(data['release_year'].median()))
# Out:
# Movies released from the year 1920 are available in the above OTT platforms
# Many movies released in the year 2016 are available in the above OTT platforms

# %% [markdown]
# Visualization related to the Release_Year in the dataset

# %%
sns.distplot(data['release_year'])
plt.axvline(data['release_year'].min(),color='green',label='min')
plt.axvline(data['release_year'].max(),color='red',label='max')
plt.axvline(data['release_year'].median(),color='yellow',label='median')
plt.legend()
# Out:
# <ipython-input-30-798a4a6f4cf4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['release_year'])

# %%
print(data['release_year'].value_counts().head(50))
# Out:
# 2019    2470
# 2020    2406
# 2021    2385
# 2018    2105
# 2017    1892
# 2016    1649
# 2015    1147
# 2014     922
# 2013     735
# 2012     649
# 2011     575
# 2010     492
# 2009     414
# 2008     386
# 2007     334
# 2006     323
# 2005     266
# 2004     232
# 2003     202
# 2002     189
# 2001     173
# 2000     167
# 1999     150
# 1998     138
# 1997     135
# 1995     125
# 1996     117
# 1993     115
# 1994     113
# 1992      96
# 1989      78
# 1990      76
# 1988      76
# 1991      75
# 1986      66
# 1985      53
# 1987      52
# 1984      51
# 1981      42
# 1982      42
# 1980      42
# 1975      41
# 1974      38
# 1979      37
# 1978      36
# 1936      35
# 1983      34
# 1972      34
# 1973      32
# 1953      31
# Name: release_year, dtype: int64

# %% [markdown]
# Genre visualization and analysis

# %%
data_Genre=data.copy()
del data_Genre['listed_in']
s = data['listed_in'].str.split(',').apply(pd.Series, 1).stack()
s.index = s.index.droplevel(-1)
s.name = 'listed_in'
data_Genre = data_Genre.join(s)

# %%
data_Genre.head()
# Out:
#    Unnamed: 0 show_id   type                 title      director  \
# 0           0      s1  Movie   The Grand Seduction  Don McKellar
# 0           0      s1  Movie   The Grand Seduction  Don McKellar
# 1           1      s2  Movie  Take Care Good Night  Girish Joshi
# 1           1      s2  Movie  Take Care Good Night  Girish Joshi
# 2           2      s3  Movie  Secrets of Deception   Josh Webber
#
#                                                 cast        country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent         Canada
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent         Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          India
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...  United States
#
#        date_added  release_year rating duration  \
# 0  March 30, 2021          2014      0  113 min
# 0  March 30, 2021          2014      0  113 min
# ...

# %% [markdown]
# Clustered Analysis due to different genres that are present in a single Coloumn

# %%
genre_counts = data['listed_in'].value_counts()
plt.figure(figsize=(10, 6))
sns.barplot(x=genre_counts.index, y=genre_counts.values)
plt.xticks(rotation=45)
plt.xlabel('listed_in')
plt.ylabel('Number of Content')
plt.title('Distribution of Content by Genre')
plt.tight_layout()
plt.show()

# %% [markdown]
# Implementing the frequnecy of each genre from all genres using "Word_cloud". This shows the most liked genre across all the movies in the dataset. This basically shows that the OTT platforms are more interested to buy these genres which typliaclly shows the choice of Genres among the audiences.

# %%
lis=[]
for i in data_Genre['listed_in']:
    lis.append(i)

for k in range(0,len(lis)):
    lis[k]=str(lis[k]).strip()

from collections import Counter
genre_count = Counter(lis)

from wordcloud import WordCloud
wc = WordCloud(background_color='white')
wc.generate_from_frequencies(genre_count)
plt.figure(figsize=(12,8))
plt.imshow(wc,interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Indiviual Genre analysis under different platforms

# %%
fig,axes=plt.subplots(1,2,figsize=(15,5))
data_Genre.loc[data_Genre['Netflix_data']==1,'listed_in'].value_counts().plot(kind='bar',ax=axes[0],color='orangered')
data_Genre.loc[data_Genre['Hulu_data']==1,'listed_in'].value_counts().plot(kind='bar',ax=axes[1],color='forestgreen')

axes[0].set_title('Netflix Genres')
axes[1].set_title('Hulu Genres')

plt.show()

# %%
fig,axes=plt.subplots(1,2,figsize=(15,5))
data_Genre.loc[data_Genre['Amazon_data']==1,'listed_in'].value_counts().plot(kind='bar',ax=axes[0],color='indigo')
data_Genre.loc[data_Genre['Disney+Hotstar_data']==1,'listed_in'].value_counts().plot(kind='bar',ax=axes[1],color='crimson')

axes[0].set_title('Amazon Genres')
axes[1].set_title('Disney+ Genres')

plt.show()

# %%
data.head(100)
# Out:
#     Unnamed: 0 show_id     type                              title  \
# 0            0      s1    Movie                The Grand Seduction
# 1            1      s2    Movie               Take Care Good Night
# 2            2      s3    Movie               Secrets of Deception
# 3            3      s4    Movie                 Pink: Staying True
# 4            4      s5    Movie                      Monster Maker
# ..         ...     ...      ...                                ...
# 95          95     s96    Movie  William and Kate: Into the Future
# 96          96     s97    Movie                           Wildlike
# 97          97     s98    Movie                         Wildfire 7
# 98          98     s99  TV Show                     Wildest Places
# 99          99    s100    Movie                      Wilder Napalm
#
#               director                                               cast  \
# 0         Don McKellar     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent
# ...

# %% [markdown]
# Checking the types of the columns

# %%
result=data.dtypes
print(result)
# Out:
# Unnamed: 0              int64
# show_id                object
# type                   object
# title                  object
# director               object
# cast                   object
# country                object
# date_added             object
# release_year            int64
# rating                 object
# duration               object
# listed_in              object
# description            object
# platform               object
# Netflix_data            int64
# Amazon_data             int64
# Disney+Hotstar_data     int64
# Hulu_data               int64
# Movie_Data              int64
# TV_Show_Data            int64
# dtype: object

# %% [markdown]
# Converting the Rating column into numeric value to plot the graph for the better analysis

# %%
columns_to_convert = ['rating']
data[columns_to_convert] = data[columns_to_convert].apply(pd.to_numeric, errors='coerce')
data.to_csv(csv_path, index=False)

# %%
data.dtypes
# Out:
# Unnamed: 0               int64
# show_id                 object
# type                    object
# title                   object
# director                object
# cast                    object
# country                 object
# date_added              object
# release_year             int64
# rating                 float64
# duration                object
# listed_in               object
# description             object
# platform                object
# Netflix_data             int64
# Amazon_data              int64
# Disney+Hotstar_data      int64
# Hulu_data                int64
# Movie_Data               int64
# TV_Show_Data             int64
# dtype: object

# %%
rating_counts=data['rating'].value_counts()

# %% [markdown]
# Ploting of the Graph based on the rating that actually shows the Age group that is suitable for the different age group to watch.
#
# This will help in selecting the movie to watch.

# %%
sns.barplot(x=rating_counts.index, y=rating_counts.values)
plt.xlabel('Rating')
plt.ylabel('Ratings')
plt.title('Number of Movies on Different Rating to watch')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Analysis Rregarding the directors that too will help in the analysis of the dataset that will help in the selection of the movies or shows based on the direction

# %%
movie_director=data_Genre.copy()
s=movie_director['director'].str.split(',').apply(pd.Series).stack()
del movie_director['director']
s.index=s.index.droplevel(-1)
s.name='director'
movie_director=movie_director.join(s)

# %%
movie_director.drop_duplicates(inplace=True)
movie_director.head()
# Out:
#    Unnamed: 0 show_id   type                 title  \
# 0           0      s1  Movie   The Grand Seduction
# 0           0      s1  Movie   The Grand Seduction
# 1           1      s2  Movie  Take Care Good Night
# 1           1      s2  Movie  Take Care Good Night
# 2           2      s3  Movie  Secrets of Deception
#
#                                                 cast        country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent         Canada
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent         Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          India
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...  United States
#
#        date_added  release_year rating duration  \
# 0  March 30, 2021          2014      0  113 min
# 0  March 30, 2021          2014      0  113 min
# 1  March 30, 2021          2018     13  110 min
# ...

# %%
movie_director['director'].value_counts().head(10)
# Out:
# Jay Chapman           182
# Mark Knight           165
# Manny Rodriguez       119
# Brian Volk-Weiss       88
# Cannis Holder          63
# Arthur van Merwijk     58
# D.J. Viola             51
# Jay Karas              50
# John Lasseter          48
# John Asher             44
# Name: director, dtype: int64

# %%
movie_director_10=data_Genre.copy()
s=movie_director['director'].str.split(',').apply(pd.Series).stack()
del movie_director['director']
s.index=s.index.droplevel(-1)
s.name='director'
movie_director_10=movie_director.join(s)

# %%
movie_director_10['director'].value_counts().head(10).plot(kind='bar')
plt.title('Top 10 Directors based on movie count across all OTT platforms')
plt.show()
